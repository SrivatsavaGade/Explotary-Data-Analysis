# %% [markdown]
# <h4>   1. IMPORTING LIBRARIES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
file = pd.read_csv("juxtaposition.csv")
file.head(3).append(file.tail(3))
# Out:
#       brand           model base_color processor screen_size  ROM  RAM  \
# 0     Apple       iPhone SE      Black     Water  Very Small   64    4
# 1     Apple  iPhone 12 Mini        Red   Ceramic       Small   64    6
# 2     Apple       iPhone SE        Red     Water  Very Small   64    4
# 427  Xiaomi      Mi 11 Lite     Others  Qualcomm       Large  128    6
# 428  Xiaomi   Redmi 8A Dual       Blue  Qualcomm      Medium   32    4
# 429  Xiaomi     Redmi 6 Pro       Blue  Qualcomm       Small   32    4
#
#      display_size  num_rear_camera  num_front_camera  battery_capacity  \
# 0             4.7                1                 1              1800
# 1             5.4                2                 1              2815
# 2             4.7                1                 1              1800
# 427           6.5                3                 1              4250
# 428           6.2                2                 1              5000
# ...

# %% [markdown]
# <h4> de

# %%
file.describe()
# Out:
#               ROM         RAM  display_size  num_rear_camera  \
# count  430.000000  430.000000    430.000000       430.000000
# mean   105.748837    5.769767      6.369767         2.904651
# std     63.164064    1.847450      0.369549         0.952350
# min      8.000000    3.000000      4.700000         1.000000
# 25%     64.000000    4.000000      6.300000         2.000000
# 50%    128.000000    6.000000      6.500000         3.000000
# 75%    128.000000    6.000000      6.500000         4.000000
# max    512.000000   12.000000      7.600000         4.000000
#
#        num_front_camera  battery_capacity     ratings  num_of_ratings  \
# count        430.000000        430.000000  430.000000      430.000000
# mean           1.044186       4529.397674    4.339302    23567.944186
# std            0.227280        986.907252    0.151494    56096.277784
# min            1.000000       1800.000000    3.000000        4.000000
# ...

# %% [markdown]
# <h1> DATA VISUALISATION :

# %% [markdown]
# <h4> INFERING THE TARGETED COLUMN SALES_PRICE WITH RESPECTIVE TO ALL OTHER FACTORS

# %% [markdown]
# <h4>                                  Brand

# %%
file["brand"].value_counts()
# Out:
# Realme     138
# Samsung    119
# Xiaomi      61
# Apple       56
# Poco        56
# Name: brand, dtype: int64

# %%
sns.histplot(file['brand'],kde=True)
# Out:
# <AxesSubplot:xlabel='brand', ylabel='Count'>

# %%
plt.figure(figsize = (25,15))
sns.pointplot(x='model',y='sales_price',hue='brand',data=file)
# Out:
# <AxesSubplot:xlabel='model', ylabel='sales_price'>

# %% [markdown]
# <h4>we can observe that samsung models are reason for high sales price

# %%
plt.figure(figsize = (25,15))
sns.pointplot(x='ROM',y='sales_price',hue='brand',data=file)
# Out:
# <AxesSubplot:xlabel='ROM', ylabel='sales_price'>

# %% [markdown]
# <h4> if the ROM is greater than 256 and the brand is samsung then there is a high chance of price being high

# %%
file["RAM"].value_counts()
# Out:
# 4     169
# 6     158
# 8      88
# 12     12
# 3       3
# Name: RAM, dtype: int64

# %%
plt.figure(figsize = (25,15))
sns.pointplot(x='RAM',y='sales_price',hue='brand',data=file)
# Out:
# <AxesSubplot:xlabel='RAM', ylabel='sales_price'>

# %% [markdown]
# <h4> if the RAM is greater than 8 and the model is samsung then the chance of price being high is high

# %%
file["base_color"].value_counts()
# Out:
# Blue      117
# Black     112
# White      44
# Silver     32
# Others     28
# Green      24
# Red        21
# Gray       20
# Yellow     11
# Gold       11
# Purple      5
# Bronze      5
# Name: base_color, dtype: int64

# %%
plt.figure(figsize = (25,15))
sns.pointplot(x='base_color',y='sales_price',hue='brand',data=file)
# Out:
# <AxesSubplot:xlabel='base_color', ylabel='sales_price'>

# %% [markdown]
# <h4> THE SAMSUNG BRAND HAVING THE COLOUR BRONZE IS HAVING HIGHEST PRICE

# %%
plt.figure(figsize = (25,15))
sns.pointplot(x='processor',y='sales_price',hue='brand',data=file)
# Out:
# <AxesSubplot:xlabel='processor', ylabel='sales_price'>

# %%
file["processor"].value_counts()
# Out:
# Qualcomm    168
# MediaTek    144
# Exynos       53
# Ceramic      33
# iOS          12
# Water        11
# Others        9
# Name: processor, dtype: int64

# %% [markdown]
# <h4>

# %% [markdown]
# <h4> since there are no processors named water and ciremic, there is an unwanted data, so we are going to change the processors to iOS

# %%
#map={'water':'iOS','Ceramic':'iOS','iOS':'iOS','Media Tek processor':'Media Tek processor}
file['processor'].replace({'Water':'iOS','Ceramic':'iOS'},inplace=True)

# %%
file['processor'].unique()
# Out:
# array(['iOS', 'MediaTek', 'Qualcomm', 'Others', 'Exynos'], dtype=object)

# %%
plt.figure(figsize = (25,15))
sns.pointplot(x='processor',y='sales_price',hue='brand',data=file)
# Out:
# <AxesSubplot:xlabel='processor', ylabel='sales_price'>

# %% [markdown]
# <h4> THE APPLE PROCESSOR IS HAVING THE HIGH PRICE

# %%
plt.figure(figsize = (25,15))
sns.pointplot(x='display_size',y='sales_price',hue='brand',data=file)
# Out:
# <AxesSubplot:xlabel='display_size', ylabel='sales_price'>

# %% [markdown]
# <h3> THE SAMSUNG MODEL HAVING LARGER DISPLAY IS EFFECTING THE SALES_PRICE

# %%
plt.figure(figsize = (25,15))
sns.pointplot(x='num_rear_camera',y='sales_price',hue='brand',data=file)
# Out:
# <AxesSubplot:xlabel='num_rear_camera', ylabel='sales_price'>

# %% [markdown]
# <h3> THE APPLE PHONE WITH TWO REAR CAMERAS EFFECTS THE SALES_PRICE

# %%
plt.figure(figsize = (25,15))
sns.pointplot(x='num_front_camera',y='sales_price',hue='brand',data=file)
# Out:
# <AxesSubplot:xlabel='num_front_camera', ylabel='sales_price'>

# %% [markdown]
# <h4> THE APPLE PHONE WITH TWO FORNT CAMERAS EFFECTS THE SALES_PRICE
